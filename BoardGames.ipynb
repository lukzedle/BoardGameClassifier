# %% [markdown]
# # Description

# %% [markdown]
# The goal of the Board Game Classifier project is to develop a model capable of accurately classifying board game names by analyzing images of game elements. By leveraging advanced image recognition techniques and a comprehensive database of board game images, the aim is to enable the model to identify key features such as game boards, cards, tokens, and dice, and determine the most probable associated board game. This project aims to provide a valuable tool to assist board game enthusiasts, collectors, and researchers in rapidly identifying unknown board games based on visual cues.

# %% [markdown]
# # Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/BoardGames
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/BoardGames

# %%
import requests
from bs4 import BeautifulSoup
import time
import  random
import os
from io import BytesIO
from PIL import Image
import cv2
import html
import numpy as np
import time
import shutil
import filecmp
import joblib
import json
import time
import datetime

from tensorflow.keras.applications import EfficientNetB0
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from keras.callbacks import EarlyStopping

# %% [markdown]
# ## Install selenium

# %%
# !pip install selenium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting selenium
#   Downloading selenium-4.10.0-py3-none-any.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 41.5 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (1.26.16)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 37.2 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.10.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2023.5.7)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Collecting async-generator>=1.9 (from trio~=0.17->selenium)
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.1.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.3 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, async-generator, wsproto, trio, trio-websocket, selenium
# Successfully installed async-generator-1.10 h11-0.14.0 outcome-1.2.0 selenium-4.10.0 trio-0.22.0 trio-websocket-0.10.3 wsproto-1.2.0

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium import webdriver
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# %%
# %%shell
#
# # Add debian buster
# cat > /etc/apt/sources.list.d/debian.list <<'EOF'
# deb [arch=amd64 signed-by=/usr/share/keyrings/debian-buster.gpg] http://deb.debian.org/debian buster main
# deb [arch=amd64 signed-by=/usr/share/keyrings/debian-buster-updates.gpg] http://deb.debian.org/debian buster-updates main
# deb [arch=amd64 signed-by=/usr/share/keyrings/debian-security-buster.gpg] http://deb.debian.org/debian-security buster/updates main
# EOF
#
# # Add keys
# apt-key adv --keyserver keyserver.ubuntu.com --recv-keys DCC9EFBF77E11517
# apt-key adv --keyserver keyserver.ubuntu.com --recv-keys 648ACFD622F3D138
# apt-key adv --keyserver keyserver.ubuntu.com --recv-keys 112695A0E562B32A
#
# apt-key export 77E11517 | gpg --dearmour -o /usr/share/keyrings/debian-buster.gpg
# apt-key export 22F3D138 | gpg --dearmour -o /usr/share/keyrings/debian-buster-updates.gpg
# apt-key export E562B32A | gpg --dearmour -o /usr/share/keyrings/debian-security-buster.gpg
#
# # Prefer debian repo for chromium* packages only
# # Note the double-blank lines between entries
# cat > /etc/apt/preferences.d/chromium.pref << 'EOF'
# Package: *
# Pin: release a=eoan
# Pin-Priority: 500
#
#
# Package: *
# Pin: origin "deb.debian.org"
# Pin-Priority: 300
#
#
# Package: chromium*
# Pin: origin "deb.debian.org"
# Pin-Priority: 700
# EOF
# Out:
# Executing: /tmp/apt-key-gpghome.tS00AyZWla/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys DCC9EFBF77E11517
# gpg: key DCC9EFBF77E11517: public key "Debian Stable Release Key (10/buster) <debian-release@lists.debian.org>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Executing: /tmp/apt-key-gpghome.VOXARhffaB/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys 648ACFD622F3D138
# gpg: key DC30D7C23CBBABEE: public key "Debian Archive Automatic Signing Key (10/buster) <ftpmaster@debian.org>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Executing: /tmp/apt-key-gpghome.8LoUgYQsTU/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys 112695A0E562B32A
# gpg: key 4DFAB270CAA96DFA: public key "Debian Security Archive Automatic Signing Key (10/buster) <ftpmaster@debian.org>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Warning: apt-key output should not be parsed (stdout is not a terminal)
# Warning: apt-key output should not be parsed (stdout is not a terminal)
# Warning: apt-key output should not be parsed (stdout is not a terminal)

# %%
# !apt-get update
# !apt-get install chromium chromium-driver
# Out:
# Get:1 http://deb.debian.org/debian buster InRelease [122 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Get:3 http://deb.debian.org/debian buster-updates InRelease [56.6 kB]
# Get:4 http://deb.debian.org/debian-security buster/updates InRelease [34.8 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1,581 B]
# Get:6 http://deb.debian.org/debian buster/main amd64 Packages [10.7 MB]
# Get:7 http://deb.debian.org/debian buster-updates/main amd64 Packages [9,745 B]
# Get:8 http://deb.debian.org/debian-security buster/updates/main amd64 Packages [667 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [1,059 kB]
# Hit:11 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:12 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:14 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:15 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease [18.1 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,360 kB]
# Hit:18 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:19 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:20 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,299 kB]
# Get:21 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal/main amd64 Packages [29.5 kB]
# Fetched 17.7 MB in 3s (5,658 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   chromium-common chromium-sandbox libevent-2.1-6 libfontenc1 libicu63
#   libimobiledevice6 libjpeg62-turbo libplist3 libre2-5 libu2f-udev libudev1
#   libupower-glib3 libusbmuxd6 libvpx5 libxkbfile1 libxtst6 libxxf86dga1
#   notification-daemon udev upower usbmuxd x11-utils
# Suggested packages:
#   chromium-l10n chromium-shell libusbmuxd-tools mesa-utils
# The following NEW packages will be installed:
#   chromium chromium-common chromium-driver chromium-sandbox libevent-2.1-6
#   libfontenc1 libicu63 libimobiledevice6 libjpeg62-turbo libplist3 libre2-5
#   libu2f-udev libupower-glib3 libusbmuxd6 libvpx5 libxkbfile1 libxtst6
#   libxxf86dga1 notification-daemon udev upower usbmuxd x11-utils
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 23 newly installed, 0 to remove and 13 not upgraded.
# Need to get 76.2 MB of archives.
# After this operation, 266 MB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian buster/main amd64 libevent-2.1-6 amd64 2.1.8-stable-4 [177 kB]
# Get:2 http://deb.debian.org/debian buster/main amd64 libicu63 amd64 63.1-6+deb10u3 [8,293 kB]
# Get:3 http://deb.debian.org/debian buster/main amd64 libjpeg62-turbo amd64 1:1.5.2-2+deb10u1 [133 kB]
# Get:4 http://deb.debian.org/debian buster/main amd64 libvpx5 amd64 1.7.0-3+deb10u1 [800 kB]
# Get:5 http://deb.debian.org/debian buster/main amd64 chromium-common amd64 90.0.4430.212-1~deb10u1 [1,423 kB]
# Get:6 http://deb.debian.org/debian buster/main amd64 chromium amd64 90.0.4430.212-1~deb10u1 [58.3 MB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libudev1 amd64 245.4-4ubuntu3.22 [75.4 kB]
# Get:8 http://deb.debian.org/debian buster/main amd64 chromium-driver amd64 90.0.4430.212-1~deb10u1 [4,703 kB]
# Get:9 http://deb.debian.org/debian buster/main amd64 chromium-sandbox amd64 90.0.4430.212-1~deb10u1 [146 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 udev amd64 245.4-4ubuntu3.22 [1,366 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 libre2-5 amd64 20200101+dfsg-1build1 [162 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontenc1 amd64 1:1.1.4-0ubuntu1 [14.0 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbfile1 amd64 1:1.1.0-1 [65.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/main amd64 libxtst6 amd64 2:1.2.3-1 [12.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu1 [12.0 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 x11-utils amd64 7.7+5 [199 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/main amd64 libplist3 amd64 2.1.0-4build2 [31.6 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal/main amd64 libusbmuxd6 amd64 2.0.1-2 [19.1 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal/main amd64 libimobiledevice6 amd64 1.2.1~git20191129.9f79242-1build1 [65.2 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 libu2f-udev all 1.1.10-1 [6,108 B]
# Get:21 http://archive.ubuntu.com/ubuntu focal/main amd64 libupower-glib3 amd64 0.99.11-1build2 [43.2 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal/universe amd64 notification-daemon amd64 3.20.0-4 [37.0 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal/main amd64 upower amd64 0.99.11-1build2 [104 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal/main amd64 usbmuxd amd64 1.1.1~git20191130.9af2b12-1 [38.4 kB]
# Fetched 76.2 MB in 3s (23.8 MB/s)
# (Reading database ... 123069 files and directories currently installed.)
# Preparing to unpack .../libudev1_245.4-4ubuntu3.22_amd64.deb ...
# Unpacking libudev1:amd64 (245.4-4ubuntu3.22) over (245.4-4ubuntu3.21) ...
# Setting up libudev1:amd64 (245.4-4ubuntu3.22) ...
# Selecting previously unselected package udev.
# (Reading database ... 123069 files and directories currently installed.)
# Preparing to unpack .../00-udev_245.4-4ubuntu3.22_amd64.deb ...
# Unpacking udev (245.4-4ubuntu3.22) ...
# Selecting previously unselected package libevent-2.1-6:amd64.
# Preparing to unpack .../01-libevent-2.1-6_2.1.8-stable-4_amd64.deb ...
# Unpacking libevent-2.1-6:amd64 (2.1.8-stable-4) ...
# Selecting previously unselected package libicu63:amd64.
# Preparing to unpack .../02-libicu63_63.1-6+deb10u3_amd64.deb ...
# Unpacking libicu63:amd64 (63.1-6+deb10u3) ...
# Selecting previously unselected package libjpeg62-turbo:amd64.
# Preparing to unpack .../03-libjpeg62-turbo_1%3a1.5.2-2+deb10u1_amd64.deb ...
# Unpacking libjpeg62-turbo:amd64 (1:1.5.2-2+deb10u1) ...
# Selecting previously unselected package libre2-5:amd64.
# Preparing to unpack .../04-libre2-5_20200101+dfsg-1build1_amd64.deb ...
# Unpacking libre2-5:amd64 (20200101+dfsg-1build1) ...
# Selecting previously unselected package libvpx5:amd64.
# Preparing to unpack .../05-libvpx5_1.7.0-3+deb10u1_amd64.deb ...
# Unpacking libvpx5:amd64 (1.7.0-3+deb10u1) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../06-libfontenc1_1%3a1.1.4-0ubuntu1_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../07-libxkbfile1_1%3a1.1.0-1_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../08-libxtst6_2%3a1.2.3-1_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../09-libxxf86dga1_2%3a1.1.5-0ubuntu1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../10-x11-utils_7.7+5_amd64.deb ...
# Unpacking x11-utils (7.7+5) ...
# Selecting previously unselected package chromium-common.
# Preparing to unpack .../11-chromium-common_90.0.4430.212-1~deb10u1_amd64.deb ...
# Unpacking chromium-common (90.0.4430.212-1~deb10u1) ...
# Selecting previously unselected package chromium.
# Preparing to unpack .../12-chromium_90.0.4430.212-1~deb10u1_amd64.deb ...
# Unpacking chromium (90.0.4430.212-1~deb10u1) ...

# %% [markdown]
# #Scrapping

# %%
url = f'https://boardgamegeek.com/image/2702639/pandemic-legacy-season-1'

content = requests.get(url).content
soup = BeautifulSoup(content, 'html.parser')

print(soup.prettify())
soup.find('link', {'as': 'image'})['href']

# %%
import os
import shutil
import random
import filecmp
import time
import requests
import cv2
import numpy as np
from PIL import Image
from io import BytesIO
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By

class BoardGamesScraper:
    """A class for scraping board game data and images from BoardGameGeek."""

    def __init__(self):
        """Initialize the BoardGamesScraper class."""
        self.base_url = 'https://boardgamegeek.com/browse/boardgame/page/'
        self.urls = []
        self.path = 'images/raw'

    def web_driver(self):
        """Create and return a WebDriver instance for Chrome."""
        options = webdriver.ChromeOptions()
        options.add_argument("--verbose")
        options.add_argument('--no-sandbox')
        options.add_argument('--headless')
        options.add_argument('--disable-gpu')
        options.add_argument("--window-size=1920, 1200")
        options.add_argument('--disable-dev-shm-usage')
        driver = webdriver.Chrome(options=options)
        return driver

    def get_urls(self, page):
        """
        Retrieve the URLs of board games from a page.

        Args:
            page (str): The URL of the page to scrape.

        Returns:
            list: A list of URLs of board games.
        """
        content = requests.get(page).content
        time.sleep(1)
        soup = BeautifulSoup(content, 'html.parser')
        return ['https://boardgamegeek.com' + link['href'] for link in soup.find_all('a', {'class': 'primary'})]

    def get_img_urls(self, url):
        """
        Retrieve the image URLs of a board game.

        Args:
            url (str): The URL of the board game.

        Returns:
            dict: A dictionary mapping the board game title to a list of image URLs.
        """
        images_urls = []
        title = url.split('/')[-1]
        base_url = url + '/images' + f'?pageid='
        driver = self.web_driver()
        driver.get(base_url + '1' + '&gallery=game&tag=')
        time.sleep(0.25)
        try:
            last_page = int(driver.find_elements(By.XPATH, '//a[@ng-click="selectPage(totalPages)"]')[0]
                            .get_attribute('innerHTML'))
            print(last_page)
        except Exception as e:
            print(f'{e}')
        driver.quit()
        for page in range(1, last_page + 1):
            page_url = base_url + str(page) + '&gallery=game&tag='
            driver = self.web_driver()
            driver.get(page_url)
            time.sleep(0.25)
            images_urls += [element.get_attribute('href') for element in
                            driver.find_elements(By.CLASS_NAME, "summary-image-thumbnail")]
            driver.quit()
        print(title, len(images_urls), len(set(images_urls)))
        return {title: images_urls}

    def get_url_img_to_download(self, url):
        """
        Get the URL of the image to download from the page of a board game.

        Args:
            url (str): The URL of the board game page.

        Returns:
            str: The URL of the image to download.
        """
        content = requests.get(url).content
        time.sleep(0.1)
        soup = BeautifulSoup(content, 'html.parser')
        return soup.find('link', {'as': 'image'})['href']

    def get_image(self, url):
        """
        Download and retrieve the image from a given URL.

        Args:
            url (str): The URL of the image to download.

        Returns:
            np.array: The image as a NumPy array.
        """
        try:
            content = requests.get(url).content
            time.sleep(0.1)
            img = Image.open(BytesIO(content))
            img = np.array(img)
            return img
        except Exception as e:
            print(f'Error: {e}')

    def save_image(self, img, url, title, path):
        """
        Save the image to the specified path.

        Args:
            img (np.array): The image as a NumPy array.
            url (str): The URL of the image.
            title (str): The title of the board game.
            path (str): The path to save the image.
        """
        try:
            file_name = url.split('/')[-1].split('.')[0] + url.split('/')[-2].split('.')[0] + '.jpg'
            os.makedirs(f'{path}/{title}', exist_ok=True)
            cv2.imwrite(f'{path}/{title}/{file_name}', cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
        except Exception as e:
            print(f'{e}')

    def get_data(self, start_page, end_page, limit_games=False, games_start=None, games_stop=None):
        """
        Scrape board game data and images from BoardGameGeek.

        Args:
            start_page (int): The starting page number to scrape.
            end_page (int): The ending page number to scrape.
            limit_games (bool): Whether to limit the number of games to scrape.
            games_start (int): The starting index of the games to scrape.
            games_stop (int): The ending index of the games to scrape.
        """
        self.urls = []
        for page in range(start_page, end_page + 1):
            self.urls += self.get_urls(self.base_url + f'{page}?sort=numvoters&sortdir=desc')
        if not limit_games:
            range_start = 0
            range_stop = len(self.urls)
        else:
            if games_start is not None:
                range_start = games_start
            else:
                range_start = 0

            if games_stop is not None:
                range_stop = games_stop
            else:
                range_stop = len(self.urls)

        for count, url in enumerate(self.urls[range_start: range_stop]):
            game_details = self.get_img_urls(url)

            for title, urls in game_details.items():
                for url in urls:
                    img_url = self.get_url_img_to_download(url)
                    img = self.get_image(img_url)
                    self.save_image(img, url, title, self.path)

    def organize_folders(self, source_folder, destination_folder, num_random_files):
        """
        Organize the game images into different folders.

        Args:
            source_folder (str): The path of the source folder containing game images.
            destination_folder (str): The path of the destination folder to organize the images.
            num_random_files (int): The number of random files to copy to the 'rest' folder.
        """
        game_folder_main = self.generate_unique_list(self.get_folder_info(destination_folder), self.get_folder_info(source_folder).keys())
        game_folders_rand = [folder for folder in os.listdir(source_folder) if
                          os.path.isdir(os.path.join(source_folder, folder))]

        for game_name in game_folder_main:
            print(game_name)
            rest_images = []
            game_folder_path = os.path.join(source_folder, game_name)
            same_folder_path = os.path.join(destination_folder, game_name, game_name)
            rest_folder_path = os.path.join(destination_folder, game_name, 'rest')
            os.makedirs(same_folder_path, exist_ok=True)
            os.makedirs(rest_folder_path, exist_ok=True)

            game_images = [item for item in os.listdir(game_folder_path) if item.endswith(('.jpg', '.png'))]

            for image in game_images:
                image_path = os.path.join(game_folder_path, image)
                shutil.copy(image_path, same_folder_path)

            other_game_folders = [folder for folder in game_folders_rand if folder != game_name]
            random_num = int(num_random_files / len(other_game_folders))
            for other_game_folder in other_game_folders:
                other_game_folder_path = os.path.join(source_folder, other_game_folder)
                other_game_images = [item for item in os.listdir(other_game_folder_path) if
                                      item.endswith(('.jpg', '.png'))]
                random_images = random.sample(other_game_images, random_num)

                for image in random_images:
                    image_path = os.path.join(other_game_folder_path, image)
                    shutil.copy(image_path, rest_folder_path)

    def get_folder_info(self, directory):
        """
        Get information about the folders in a directory.

        Args:
            directory (str): The path of the directory.

        Returns:
            dict: A dictionary containing the folder names as keys and their paths as values.
        """
        location_details = {}
        items = os.listdir(directory)
        for item in items:
            path = os.path.join(directory, item)
            if os.path.isdir(path):
                location_details[item] = path
        return location_details

    def generate_unique_list(self, list1, list2):
        """
        Generate a unique list by combining two lists and removing duplicates.

        Args:
            list1 (list): The first list.
            list2 (list): The second list.

        Returns:
            list: A unique list containing elements from both lists.
        """
        unique_list = []
        for item in list1:
            if item not in list2:
                unique_list.append(item)
        for item in list2:
            if item not in list1:
                unique_list.append(item)
        return unique_list

    def create_train_test_folders(self, source_directory, destination_directory, train_ratio=0.2):
        """
        Create train and test folders with shuffled data.

        Args:
            source_directory (str): The path of the source directory.
            destination_directory (str): The path of the destination directory.
            train_ratio (float): The ratio of training data to total data.
        """
        train_directory = os.path.join(destination_directory, "train")
        test_directory = os.path.join(destination_directory, "test")

        os.makedirs(train_directory, exist_ok=True)
        os.makedirs(test_directory, exist_ok=True)

        subdirectories = os.listdir(source_directory)

        for subdir in subdirectories:

            train_subdir = os.path.join(train_directory, subdir)
            test_subdir = os.path.join(test_directory, subdir)

            os.makedirs(train_subdir, exist_ok=True)
            os.makedirs(test_subdir, exist_ok=True)

            files = os.listdir(os.path.join(source_directory, subdir))
            random.shuffle(files)
            split_index = int(len(files) * train_ratio)

            train_files = files[split_index:]
            test_files = files[:split_index]

            for game_name in train_files:
                source_path = os.path.join(source_directory, subdir, game_name)
                destination_path = os.path.join(train_subdir, game_name)
                shutil.copy2(source_path, destination_path)

            for game_name in test_files:
                source_path = os.path.join(source_directory, subdir, game_name)
                destination_path = os.path.join(test_subdir, game_name)
                shutil.copy2(source_path, destination_path)

    def compare_folders(self, folder1, folder2):
        """
        Compare two folders to check if their contents are the same.

        Args:
            folder1 (str): The path of the first folder.
            folder2 (str): The path of the second folder.

        Returns:
            bool: True if the folders have the same contents, False otherwise.
        """
        return filecmp.cmpfiles(folder1, folder2, shallow=False) == ([], [], [])

    def delete_folder(self, folder):
        """
        Delete a folder and its contents.

        Args:
            folder (str): The path of the folder to delete.
        """
        try:
            shutil.rmtree(folder)
        except Exception as e:
            print(f'Error: {e}')

# %%
games_scraper = BoardGamesScraper()

# %%
games_scraper.organize_folders('images/games', 'images/testing_area/two_classes',  200)

# %%
from flask import Flask, jsonify, request
import pickle
import pandas as pd

app = Flask(__name__)

@app.route('/predict', methods=['POST'])
def predict():
     json_ = request.json
     df = pd.DataFrame(json_)
     X = df[['LSTAT']]
     prediction = clf.predict(X)
     return jsonify({'prediction': list(prediction)})

if __name__ == '__main__':
     with open('model.pickle', 'rb') as f:
          clf = pickle.load(f)

     app.run(host='0.0.0.0', port=8080)

# %%
games_list = games_scraper.get_folder_info('images/testing_area/two_classes')

# %%
for name, dir in games_list.items():
  games_scraper.create_train_test_folders(dir, f'images/testing_area/train_test/{str(name)}')
# Out:
# Category: arkham-horror
# Train items: 200
# Test items: 50
# ---------------------------
# Category: rest
# Train items: 160
# Test items: 40
# ---------------------------
# Category: carcassonne
# Train items: 601
# Test items: 150
# ---------------------------
# Category: rest
# Train items: 160
# Test items: 40
# ---------------------------
# Category: gloomhaven
# Train items: 201
# Test items: 50
# ---------------------------
# Category: rest
# Train items: 160
# Test items: 40
# ---------------------------

# %% [markdown]
# #Gloomhaven

# %% [markdown]
# ##Train

# %%
games_scraper.check_identical_files('images/testing_area/train_test/carcassonne/train', 'images/testing_area/train_test/carcassonne/test')
# Out:
# Folders are disjoint
# []

# %%
path = 'images/testing_area/train_test/gloomhaven/train'

batch_size = 8
img_height = 256
img_width = 256

# %%
train_ds = keras.utils.image_dataset_from_directory(
    path,
    validation_split=0.2,
    subset='training',
    image_size = (img_height, img_width),
    batch_size = batch_size,
    label_mode = 'categorical',
    seed = 0
)

val_ds = keras.utils.image_dataset_from_directory(
    path,
    validation_split=0.2,
    subset='validation',
    image_size = (img_height, img_width),
    batch_size = batch_size,
    label_mode = 'categorical',
    seed = 0
)
# Out:
# Found 361 files belonging to 2 classes.
# Using 289 files for training.
# Found 361 files belonging to 2 classes.
# Using 72 files for validation.

# %%
efficient_model = EfficientNetB0(include_top=False,
                                 weights='imagenet',
                                 input_shape = (img_height,
                                                img_width,
                                                3))

# %%
model_gloomhaven = Sequential()
model_gloomhaven.add(keras.layers.RandomFlip(mode="horizontal_and_vertical"))
model_gloomhaven.add(keras.layers.RandomZoom(height_factor=(-0.3, -0.2), interpolation="bilinear"))
model_gloomhaven.add(efficient_model)
model_gloomhaven.add(layers.Flatten())
model_gloomhaven.add(layers.Dense(128, activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
model_gloomhaven.add(layers.Dropout(0.5))
model_gloomhaven.add(layers.Dense(2, activation='sigmoid'))

# %%
opt = keras.optimizers.Adam(learning_rate=0.00001)
model_gloomhaven.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model_gloomhaven.fit(train_ds,
                    validation_data = val_ds,
                    epochs = 30,
                    batch_size = 8)
# Out:
# Epoch 1/30
# 37/37 [==============================] - 51s 198ms/step - loss: 1.5740 - accuracy: 0.5190 - val_loss: 1.1632 - val_accuracy: 0.6111
# Epoch 2/30
# 37/37 [==============================] - 6s 148ms/step - loss: 1.4026 - accuracy: 0.5640 - val_loss: 1.0818 - val_accuracy: 0.6528
# Epoch 3/30
# 37/37 [==============================] - 5s 117ms/step - loss: 1.1290 - accuracy: 0.7163 - val_loss: 1.0571 - val_accuracy: 0.6667
# Epoch 4/30
# 37/37 [==============================] - 5s 116ms/step - loss: 1.1930 - accuracy: 0.6955 - val_loss: 0.9931 - val_accuracy: 0.7639
# Epoch 5/30
# 37/37 [==============================] - 5s 141ms/step - loss: 1.0860 - accuracy: 0.7232 - val_loss: 0.9784 - val_accuracy: 0.7361
# Epoch 6/30
# 37/37 [==============================] - 5s 115ms/step - loss: 1.0385 - accuracy: 0.7405 - val_loss: 0.9631 - val_accuracy: 0.7500
# Epoch 7/30
# Epoch 27/30
# 37/37 [==============================] - 5s 116ms/step - loss: 0.5818 - accuracy: 0.9619 - val_loss: 0.8306 - val_accuracy: 0.8194
# Epoch 28/30
# 37/37 [==============================] - 6s 144ms/step - loss: 0.5699 - accuracy: 0.9723 - val_loss: 0.8388 - val_accuracy: 0.8056
# Epoch 29/30
# 37/37 [==============================] - 5s 116ms/step - loss: 0.5821 - accuracy: 0.9585 - val_loss: 0.8327 - val_accuracy: 0.7917
# Epoch 30/30
# 37/37 [==============================] - 5s 142ms/step - loss: 0.5506 - accuracy: 0.9723 - val_loss: 0.8273 - val_accuracy: 0.8056

# %% [markdown]
# ##Test

# %%
path = 'images/testing_area/train_test/gloomhaven/test'

batch_size = 8
img_height = 256
img_width = 256

# %%
test_ds = keras.utils.image_dataset_from_directory(path,
                                                    validation_split=None,
                                                    subset=None,
                                                    image_size = (img_height, img_width),
                                                    batch_size = batch_size,
                                                    label_mode='categorical',
                                                    interpolation='bilinear',
                                                    seed=0)
# Out:
# Found 90 files belonging to 2 classes.

# %%
test_loss, test_acc = model_gloomhaven.evaluate(test_ds)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# 12/12 [==============================] - 1s 37ms/step - loss: 0.7570 - accuracy: 0.8667
# Test loss: 0.7570341229438782
# Test accuracy: 0.8666666746139526

# %% [markdown]
# #Carcassonne

# %% [markdown]
# ##Train

# %%
path = 'images/testing_area/train_test/carcassonne/train'

batch_size = 8
img_height = 256
img_width = 256

# %%
train_ds = keras.utils.image_dataset_from_directory(
    path,
    validation_split=0.2,
    subset='training',
    image_size = (img_height, img_width),
    batch_size = batch_size,
    label_mode = 'categorical',
    seed = 0
)

val_ds = keras.utils.image_dataset_from_directory(
    path,
    validation_split=0.2,
    subset='validation',
    image_size = (img_height, img_width),
    batch_size = batch_size,
    label_mode = 'categorical',
    seed = 0
)
# Out:
# Found 761 files belonging to 2 classes.
# Using 609 files for training.
# Found 761 files belonging to 2 classes.
# Using 152 files for validation.

# %%
efficient_model = EfficientNetB0(include_top=False,
                                 weights='imagenet',
                                 input_shape = (img_height,
                                                img_width,
                                                3))

# %%
model_carcassonne = Sequential()
model_carcassonne.add(keras.layers.RandomFlip(mode="horizontal_and_vertical"))
model_carcassonne.add(keras.layers.RandomZoom(height_factor=(-0.3, -0.2), interpolation="bilinear"))
model_carcassonne.add(efficient_model)
model_carcassonne.add(layers.Flatten())
model_carcassonne.add(layers.Dense(128, activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
model_carcassonne.add(layers.Dropout(0.5))
model_carcassonne.add(layers.Dense(2, activation='sigmoid'))

# %%
opt = keras.optimizers.Adam(learning_rate=0.00001)
model_carcassonne.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model_carcassonne.fit(train_ds,
                    validation_data = val_ds,
                    epochs = 30,
                    batch_size = 8)
# Out:
# Epoch 1/30
# 77/77 [==============================] - 59s 143ms/step - loss: 1.5547 - accuracy: 0.5862 - val_loss: 0.9139 - val_accuracy: 0.7961
# Epoch 2/30
# 77/77 [==============================] - 9s 117ms/step - loss: 0.9808 - accuracy: 0.7767 - val_loss: 0.8463 - val_accuracy: 0.8355
# Epoch 3/30
# 77/77 [==============================] - 10s 132ms/step - loss: 0.8347 - accuracy: 0.8456 - val_loss: 0.8011 - val_accuracy: 0.8618
# 77/77 [==============================] - 9s 117ms/step - loss: 0.5328 - accuracy: 0.9803 - val_loss: 0.5527 - val_accuracy: 0.9671
# Epoch 24/30
# 77/77 [==============================] - 10s 127ms/step - loss: 0.5171 - accuracy: 0.9885 - val_loss: 0.5558 - val_accuracy: 0.9737
# Epoch 25/30
# 77/77 [==============================] - 10s 131ms/step - loss: 0.5039 - accuracy: 0.9869 - val_loss: 0.5550 - val_accuracy: 0.9803
# Epoch 26/30
# 77/77 [==============================] - 11s 141ms/step - loss: 0.5024 - accuracy: 0.9934 - val_loss: 0.5559 - val_accuracy: 0.9737
# Epoch 27/30
# 77/77 [==============================] - 10s 131ms/step - loss: 0.5066 - accuracy: 0.9869 - val_loss: 0.5603 - val_accuracy: 0.9671
# Epoch 28/30
# 77/77 [==============================] - 10s 132ms/step - loss: 0.4949 - accuracy: 0.9885 - val_loss: 0.5540 - val_accuracy: 0.9671
# Epoch 29/30
# 77/77 [==============================] - 10s 122ms/step - loss: 0.5072 - accuracy: 0.9819 - val_loss: 0.5418 - val_accuracy: 0.9737
# Epoch 30/30
# 77/77 [==============================] - 10s 118ms/step - loss: 0.4859 - accuracy: 0.9934 - val_loss: 0.5439 - val_accuracy: 0.9737

# %% [markdown]
# ##Train

# %%
path = 'images/testing_area/train_test/carcassonne/test'

batch_size = 8
img_height = 256
img_width = 256

# %%
test_ds = keras.utils.image_dataset_from_directory(path,
                                                    validation_split=None,
                                                    subset=None,
                                                    image_size = (img_height, img_width),
                                                    batch_size = batch_size,
                                                    label_mode='categorical',
                                                    interpolation='bilinear',
                                                    seed=0)
# Out:
# Found 190 files belonging to 2 classes.

# %%
test_loss, test_acc = model_carcassonne.evaluate(test_ds)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# 24/24 [==============================] - 2s 66ms/step - loss: 0.6328 - accuracy: 0.9474
# Test loss: 0.6327834725379944
# Test accuracy: 0.9473684430122375

# %% [markdown]
# #arkham-horror

# %% [markdown]
# ##train

# %%
path = 'images/testing_area/train_test/arkham-horror/train'

batch_size = 8
img_height = 256
img_width = 256

# %%
train_ds = keras.utils.image_dataset_from_directory(
    path,
    validation_split=0.2,
    subset='training',
    image_size = (img_height, img_width),
    batch_size = batch_size,
    label_mode = 'categorical',
    seed = 0
)

val_ds = keras.utils.image_dataset_from_directory(
    path,
    validation_split=0.2,
    subset='validation',
    image_size = (img_height, img_width),
    batch_size = batch_size,
    label_mode = 'categorical',
    seed = 0
)
# Out:
# Found 360 files belonging to 2 classes.
# Using 288 files for training.
# Found 360 files belonging to 2 classes.
# Using 72 files for validation.

# %%
efficient_model = EfficientNetB0(include_top=False,
                                 weights='imagenet',
                                 input_shape = (img_height,
                                                img_width,
                                                3))

# %%
model_arkham_horror = Sequential()
model_arkham_horror.add(keras.layers.RandomFlip(mode="horizontal_and_vertical"))
model_arkham_horror.add(keras.layers.RandomZoom(height_factor=(-0.3, -0.2), interpolation="bilinear"))
model_arkham_horror.add(efficient_model)
model_arkham_horror.add(layers.Flatten())
model_arkham_horror.add(layers.Dense(128, activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
model_arkham_horror.add(layers.Dropout(0.5))
model_arkham_horror.add(layers.Dense(2, activation='sigmoid'))

# %%
opt = keras.optimizers.Adam(learning_rate=0.00001)
model_arkham_horror.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history =
# 36/36 [==============================] - 4s 118ms/step - loss: 0.6181 - accuracy: 0.9375 - val_loss: 0.9695 - val_accuracy: 0.7778
# Epoch 20/30
# 36/36 [==============================] - 5s 123ms/step - loss: 0.5875 - accuracy: 0.9549 - val_loss: 0.9675 - val_accuracy: 0.7917
# Epoch 21/30
# 36/36 [==============================] - 6s 148ms/step - loss: 0.5982 - accuracy: 0.9549 - val_loss: 0.9695 - val_accuracy: 0.7917
# Epoch 22/30
# 36/36 [==============================] - 5s 125ms/step - loss: 0.5715 - accuracy: 0.9722 - val_loss: 0.9743 - val_accuracy: 0.7778
# Epoch 23/30
# 36/36 [==============================] - 6s 162ms/step - loss: 0.5955 - accuracy: 0.9583 - val_loss: 0.9637 - val_accuracy: 0.7917
# Epoch 24/30
# 36/36 [==============================] - 5s 118ms/step - loss: 0.5828 - accuracy: 0.9618 - val_loss: 0.9494 - val_accuracy: 0.7917
# Epoch 25/30
# 36/36 [==============================] - 6s 162ms/step - loss: 0.5676 - accuracy: 0.9688 - val_loss: 0.9565 - val_accuracy: 0.7917
# Epoch 26/30
# 36/36 [==============================] - 5s 118ms/step - loss: 0.5758 - accuracy: 0.9583 - val_loss: 0.9562 - val_accuracy: 0.7917
# Epoch 27/30
# 36/36 [==============================] - 5s 145ms/step - loss: 0.5788 - accuracy: 0.9688 - val_loss: 0.9627 - val_accuracy: 0.7778
# Epoch 28/30
# 36/36 [==============================] - 5s 118ms/step - loss: 0.5632 - accuracy: 0.9688 - val_loss: 0.9617 - val_accuracy: 0.7639
# Epoch 29/30
# 36/36 [==============================] - 4s 117ms/step - loss: 0.5467 - accuracy: 0.9792 - val_loss: 0.9611 - val_accuracy: 0.7778
# Epoch 30/30
# 36/36 [==============================] - 5s 144ms/step - loss: 0.5812 - accuracy: 0.9514 - val_loss: 0.9418 - val_accuracy: 0.8194

# %% [markdown]
# ##test

# %%
path = 'images/testing_area/train_test/arkham-horror/test'

batch_size = 8
img_height = 256
img_width = 256

# %%
test_ds = keras.utils.image_dataset_from_directory(path,
                                                    validation_split=None,
                                                    subset=None,
                                                    image_size = (img_height, img_width),
                                                    batch_size = batch_size,
                                                    label_mode='categorical',
                                                    interpolation='bilinear',
                                                    seed=0)
# Out:
# Found 90 files belonging to 2 classes.

# %%
test_loss, test_acc = model_arkham_horror.evaluate(test_ds)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# 12/12 [==============================] - 1s 32ms/step - loss: 0.7599 - accuracy: 0.9000
# Test loss: 0.7598509788513184
# Test accuracy: 0.8999999761581421

# %% [markdown]
# #All models data preparation

# %%
games_scraper.organize_folders('images/raw', 'images/all_data_sep', 800)

# %%
games_location_details = games_scraper.get_folder_info('images/all_data_sep')

# %%
len(games_location_details)
# Out:
# 241

# %%
def find_empty_parent_folders(root_directory):
    empty_parent_folders = []

    for folder_name in os.listdir(root_directory):
        folder_path = os.path.join(root_directory, folder_name)

        if os.path.isdir(folder_path):
            has_files = False
            for child_folder in os.listdir(folder_path):
                child_folder_path = os.path.join(folder_path, child_folder)

                if os.path.isdir(child_folder_path):
                    if len(os.listdir(child_folder_path)) > 0:
                        has_files = True
                        break

            if not has_files:
                empty_parent_folders.append(folder_path)

    return empty_parent_folders

# %%
def delete_folders(folders):
    for folder in folders:
        if os.path.exists(folder):
            try:
                shutil.rmtree(folder)
                print(f"Deleted folder: {folder}")
            except OSError as e:
                print(f"Error deleting folder: {folder}\n{str(e)}")
        else:
            print(f"Folder does not exist: {folder}")

# %%
find_empty_parent_folders('images/main_separated')

# %%
for name, dir in games_location_details.items():
  games_scraper.create_train_test_folders(dir, f'images/main_separated/{str(name)}')
# Out:
# Category: carcassonne
# Train items: 876
# Test items: 219
# ---------------------------
# Category: rest
# Train items: 554
# Test items: 138
# ---------------------------
# Category: catan
# Train items: 929
# Test items: 232
# ---------------------------
# Category: rest
# Train items: 568
# Test items: 142
# ---------------------------
# Category: pandemic
# Train items: 948
# Test items: 236
# ---------------------------
# Category: rest
# Train items: 560
# Test items: 140
# ---------------------------
# Category: 7-wonders
# Train items: 489
# Test items: 122
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: terraforming-mars
# Train items: 647
# Test items: 161
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: dominion
# Train items: 276
# Test items: 68
# ---------------------------
# Category: rest
# Train items: 554
# Test items: 138
# ---------------------------
# Category: codenames
# Train items: 243
# Test items: 60
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: 7-wonders-duel
# Train items: 300
# Test items: 74
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: ticket-ride
# Train items: 368
# Test items: 91
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: azul
# Train items: 479
# Test items: 119
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: wingspan
# Train items: 700
# Test items: 175
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: scythe
# Train items: 1249
# Test items: 312
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: splendor
# Train items: 343
# Test items: 85
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: ticket-ride-europe
# Train items: 477
# Test items: 119
# ---------------------------
# Category: rest
# Train items: 554
# Test items: 138
# ---------------------------
# Category: agricola
# Train items: 704
# Test items: 176
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: puerto-rico
# Train items: 328
# Test items: 82
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: small-world
# Train items: 340
# Test items: 84
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: king-tokyo
# Train items: 522
# Test items: 130
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: love-letter
# Train items: 351
# Test items: 87
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: power-grid
# Train items: 443
# Test items: 110
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: dixit
# Train items: 313
# Test items: 78
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: patchwork
# Train items: 619
# Test items: 154
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: gloomhaven
# Train items: 398
# Test items: 99
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: castles-burgundy
# Train items: 543
# Test items: 135
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: race-galaxy
# Train items: 224
# Test items: 55
# ---------------------------
# Category: rest
# Train items: 556
# Test items: 139
# ---------------------------
# Category: lords-waterdeep
# Train items: 389
# Test items: 97
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: citadels
# Train items: 377
# Test items: 94
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: stone-age
# Train items: 495
# Test items: 123
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: pandemic-legacy-season-1
# Train items: 389
# Test items: 97
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: forbidden-island
# Train items: 468
# Test items: 116
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: jaipur
# Train items: 363
# Test items: 90
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: munchkin
# Train items: 262
# Test items: 65
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: twilight-struggle
# Train items: 536
# Test items: 133
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: terra-mystica
# Train items: 585
# Test items: 146
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: hanabi
# Train items: 219
# Test items: 54
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: everdell
# Train items: 508
# Test items: 126
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: dead-winter-crossroads-game
# Train items: 358
# Test items: 89
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: viticulture-essential-edition
# Train items: 389
# Test items: 97
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: spirit-island
# Train items: 325
# Test items: 81
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: betrayal-house-hill
# Train items: 315
# Test items: 78
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: bohnanza
# Train items: 268
# Test items: 66
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: lost-cities
# Train items: 240
# Test items: 60
# ---------------------------
# Category: rest
# Train items: 560
# Test items: 140
# ---------------------------
# Category: blood-rage
# Train items: 370
# Test items: 92
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: kingdomino
# Train items: 324
# Test items: 81
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: coup
# Train items: 228
# Test items: 57
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: root
# Train items: 576
# Test items: 144
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: sushi-go
# Train items: 157
# Test items: 39
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: star-realms
# Train items: 104
# Test items: 25
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: takenoko
# Train items: 673
# Test items: 168
# ---------------------------
# Category: rest
# Train items: 568
# Test items: 142
# ---------------------------
# Category: quacks-quedlinburg
# Train items: 291
# Test items: 72
# ---------------------------
# Category: rest
# Train items: 568
# Test items: 142
# ---------------------------
# Category: robinson-crusoe-adventures-cursed-island
# Train items: 580
# Test items: 145
# ---------------------------
# Category: rest
# Train items: 554
# Test items: 138
# ---------------------------
# Category: mysterium
# Train items: 195
# Test items: 48
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: arkham-horror-card-game
# Train items: 259
# Test items: 64
# ---------------------------
# Category: rest
# Train items: 543
# Test items: 135
# ---------------------------
# Category: resistance
# Train items: 224
# Test items: 55
# ---------------------------
# Category: rest
# Train items: 554
# Test items: 138
# ---------------------------
# Category: five-tribes
# Train items: 438
# Test items: 109
# ---------------------------
# Category: rest
# Train items: 553
# Test items: 138
# ---------------------------
# Category: arkham-horror
# Train items: 545
# Test items: 136
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: clank-deck-building-adventure
# Train items: 197
# Test items: 49
# ---------------------------
# Category: rest
# Train items: 546
# Test items: 136
# ---------------------------
# Category: great-western-trail
# Train items: 226
# Test items: 56
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: brass-birmingham
# Train items: 388
# Test items: 96
# ---------------------------
# Category: rest
# Train items: 548
# Test items: 137
# ---------------------------
# Category: magic-gathering
# Train items: 310
# Test items: 77
# ---------------------------
# Category: rest
# Train items: 570
# Test items: 142
# ---------------------------
# Category: concordia
# Train items: 313
# Test items: 78
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: tzolk-mayan-calendar
# Train items: 414
# Test items: 103
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: sagrada
# Train items: 410
# Test items: 102
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: crew-quest-planet-nine
# Train items: 107
# Test items: 26
# ---------------------------
# Category: rest
# Train items: 556
# Test items: 138
# ---------------------------
# Category: santorini
# Train items: 107
# Test items: 26
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: battlestar-galactica-board-game
# Train items: 182
# Test items: 45
# ---------------------------
# Category: rest
# Train items: 532
# Test items: 132
# ---------------------------
# Category: hive
# Train items: 87
# Test items: 21
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: lost-ruins-arnak
# Train items: 276
# Test items: 68
# ---------------------------
# Category: rest
# Train items: 567
# Test items: 141
# ---------------------------
# Category: eldritch-horror
# Train items: 440
# Test items: 109
# ---------------------------
# Category: rest
# Train items: 543
# Test items: 135
# ---------------------------
# Category: chess
# Train items: 997
# Test items: 249
# ---------------------------
# Category: rest
# Train items: 572
# Test items: 143
# ---------------------------
# Category: sheriff-nottingham
# Train items: 172
# Test items: 42
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: risk
# Train items: 414
# Test items: 103
# ---------------------------
# Category: rest
# Train items: 533
# Test items: 133
# ---------------------------
# Category: dune-imperium
# Train items: 165
# Test items: 41
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: monopoly
# Train items: 878
# Test items: 219
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: mansions-madness-second-edition
# Train items: 260
# Test items: 65
# ---------------------------
# Category: rest
# Train items: 568
# Test items: 142
# ---------------------------
# Category: galaxy-trucker
# Train items: 369
# Test items: 92
# ---------------------------
# Category: rest
# Train items: 554
# Test items: 138
# ---------------------------
# Category: caverna-cave-farmers
# Train items: 267
# Test items: 66
# ---------------------------
# Category: rest
# Train items: 562
# Test items: 140
# ---------------------------
# Category: game-thrones-board-game-second-edition
# Train items: 260
# Test items: 64
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: dominion-intrigue
# Train items: 116
# Test items: 29
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: alhambra
# Train items: 320
# Test items: 79
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: mage-knight-board-game
# Train items: 664
# Test items: 165
# ---------------------------
# Category: rest
# Train items: 561
# Test items: 140
# ---------------------------
# Category: resistance-avalon
# Train items: 137
# Test items: 34
# ---------------------------
# Category: rest
# Train items: 571
# Test items: 142
# ---------------------------
# Category: sushi-go-party
# Train items: 151
# Test items: 37
# ---------------------------
# Category: rest
# Train items: 568
# Test items: 142
# ---------------------------
# Category: machi-koro
# Train items: 200
# Test items: 49
# ---------------------------
# Category: rest
# Train items: 559
# Test items: 139
# ---------------------------
# Category: cosmic-encounter
# Train items: 251
# Test items: 62
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: scrabble
# Train items: 468
# Test items: 116
# ---------------------------
# Category: rest
# Train items: 574
# Test items: 143
# ---------------------------
# Category: saboteur
# Train items: 143
# Test items: 35
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: roll-galaxy
# Train items: 223
# Test items: 55
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: exploding-kittens
# Train items: 58
# Test items: 14
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: ark-nova
# Train items: 291
# Test items: 72
# ---------------------------
# Category: rest
# Train items: 558
# Test items: 139
# ---------------------------
# Category: le-havre
# Train items: 340
# Test items: 84
# ---------------------------
# Category: rest
# Train items: 568
# Test items: 141
# ---------------------------
# Category: bang
# Train items: 178
# Test items: 44
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: colt-express
# Train items: 258
# Test items: 64
# ---------------------------
# Category: rest
# Train items: 568
# Test items: 142
# ---------------------------
# Category: istanbul
# Train items: 187
# Test items: 46
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: star-wars-rebellion
# Train items: 446
# Test items: 111
# ---------------------------
# Category: rest
# Train items: 572
# Test items: 142
# ---------------------------
# Category: forbidden-desert
# Train items: 147
# Test items: 36
# ---------------------------
# Category: rest
# Train items: 556
# Test items: 139
# ---------------------------
# Category: through-ages-new-story-civilization
# Train items: 160
# Test items: 39
# ---------------------------
# Category: rest
# Train items: 553
# Test items: 138
# ---------------------------
# Category: android-netrunner
# Train items: 111
# Test items: 27
# ---------------------------
# Category: rest
# Train items: 545
# Test items: 136
# ---------------------------
# Category: memoir-44
# Train items: 445
# Test items: 111
# ---------------------------
# Category: rest
# Train items: 575
# Test items: 143
# ---------------------------
# Category: orleans
# Train items: 276
# Test items: 69
# ---------------------------
# Category: rest
# Train items: 564
# Test items: 141
# ---------------------------
# Category: sale
# Train items: 180
# Test items: 44
# ---------------------------
# Category: rest
# Train items: 556
# Test items: 138
# ---------------------------
# Category: gloomhaven-jaws-lion
# Train items: 167
# Test items: 41
# ---------------------------
# Category: rest
# Train items: 562
# Test items: 140
# ---------------------------
# Category: cartographers
# Train items: 144
# Test items: 36
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: no-thanks
# Train items: 150
# Test items: 37
# ---------------------------
# Category: rest
# Train items: 573
# Test items: 143
# ---------------------------
# Category: descent-journeys-dark-second-edition
# Train items: 341
# Test items: 85
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: castles-mad-king-ludwig
# Train items: 304
# Test items: 76
# ---------------------------
# Category: rest
# Train items: 543
# Test items: 135
# ---------------------------
# Category: tokaido
# Train items: 230
# Test items: 57
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: star-wars-x-wing-miniatures-game
# Train items: 172
# Test items: 43
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: elder-sign
# Train items: 356
# Test items: 88
# ---------------------------
# Category: rest
# Train items: 556
# Test items: 138
# ---------------------------
# Category: survive-escape-atlantis
# Train items: 321
# Test items: 80
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: gaia-project
# Train items: 363
# Test items: 90
# ---------------------------
# Category: rest
# Train items: 551
# Test items: 137
# ---------------------------
# Category: suburbia
# Train items: 300
# Test items: 74
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: isle-skye-chieftain-king
# Train items: 112
# Test items: 28
# ---------------------------
# Category: rest
# Train items: 548
# Test items: 136
# ---------------------------
# Category: seasons
# Train items: 324
# Test items: 80
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: voyages-marco-polo
# Train items: 340
# Test items: 84
# ---------------------------
# Category: rest
# Train items: 564
# Test items: 141
# ---------------------------
# Category: century-spice-road
# Train items: 182
# Test items: 45
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: star-wars-imperial-assault
# Train items: 170
# Test items: 42
# ---------------------------
# Category: rest
# Train items: 532
# Test items: 132
# ---------------------------
# Category: imperial-settlers
# Train items: 281
# Test items: 70
# ---------------------------
# Category: rest
# Train items: 556
# Test items: 139
# ---------------------------
# Category: roborally
# Train items: 161
# Test items: 40
# ---------------------------
# Category: rest
# Train items: 557
# Test items: 139
# ---------------------------
# Category: lord-rings-card-game
# Train items: 281
# Test items: 70
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: brass-lancashire
# Train items: 382
# Test items: 95
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: flash-point-fire-rescue
# Train items: 245
# Test items: 61
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: san-juan
# Train items: 126
# Test items: 31
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: bang-dice-game
# Train items: 127
# Test items: 31
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: just-one
# Train items: 109
# Test items: 27
# ---------------------------
# Category: rest
# Train items: 567
# Test items: 141
# ---------------------------
# Category: kingdom-builder
# Train items: 328
# Test items: 82
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: village
# Train items: 371
# Test items: 92
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: troyes
# Train items: 422
# Test items: 105
# ---------------------------
# Category: rest
# Train items: 543
# Test items: 135
# ---------------------------
# Category: raiders-north-sea
# Train items: 271
# Test items: 67
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: photosynthesis
# Train items: 240
# Test items: 59
# ---------------------------
# Category: rest
# Train items: 544
# Test items: 136
# ---------------------------
# Category: keyflower
# Train items: 271
# Test items: 67
# ---------------------------
# Category: rest
# Train items: 568
# Test items: 142
# ---------------------------
# Category: legendary-marvel-deck-building-game
# Train items: 108
# Test items: 27
# ---------------------------
# Category: rest
# Train items: 554
# Test items: 138
# ---------------------------
# Category: s-pretty-clever
# Train items: 86
# Test items: 21
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: ra
# Train items: 217
# Test items: 54
# ---------------------------
# Category: rest
# Train items: 543
# Test items: 135
# ---------------------------
# Category: alchemists
# Train items: 211
# Test items: 52
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: carcassonne-expansion-1-inns-cathedrals
# Train items: 148
# Test items: 37
# ---------------------------
# Category: rest
# Train items: 552
# Test items: 138
# ---------------------------
# Category: targi
# Train items: 144
# Test items: 36
# ---------------------------
# Category: rest
# Train items: 566
# Test items: 141
# ---------------------------
# Category: 7th-continent
# Train items: 159
# Test items: 39
# ---------------------------
# Category: rest
# Train items: 560
# Test items: 140
# ---------------------------
# Category: quest-el-dorado
# Train items: 196
# Test items: 49
# ---------------------------
# Category: rest
# Train items: 566
# Test items: 141
# ---------------------------
# Category: codenames-pictures
# Train items: 104
# Test items: 25
# ---------------------------
# Category: rest
# Train items: 562
# Test items: 140
# ---------------------------
# Category: hey-s-my-fish
# Train items: 303
# Test items: 75
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: parks
# Train items: 284
# Test items: 70
# ---------------------------
# Category: rest
# Train items: 573
# Test items: 143
# ---------------------------
# Category: deception-murder-hong-kong
# Train items: 114
# Test items: 28
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: ghost-stories
# Train items: 265
# Test items: 66
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: guillotine
# Train items: 152
# Test items: 37
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: codenames-duet
# Train items: 100
# Test items: 24
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: twilight-imperium-fourth-edition
# Train items: 383
# Test items: 95
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: chronicles-crime
# Train items: 183
# Test items: 45
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: modern-art
# Train items: 321
# Test items: 80
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: skull
# Train items: 102
# Test items: 25
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: cyclades
# Train items: 307
# Test items: 76
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: marvel-champions-card-game
# Train items: 160
# Test items: 40
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: spyfall
# Train items: 70
# Test items: 17
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: onitama
# Train items: 159
# Test items: 39
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: sherlock-holmes-consulting-detective-thames-murder
# Train items: 87
# Test items: 21
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: coloretto
# Train items: 175
# Test items: 43
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: dominant-species
# Train items: 369
# Test items: 92
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: friday
# Train items: 208
# Test items: 51
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: dice-forge
# Train items: 150
# Test items: 37
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: incan-gold
# Train items: 218
# Test items: 54
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: dixit-odyssey
# Train items: 132
# Test items: 33
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: magic-maze
# Train items: 84
# Test items: 20
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: rising-sun
# Train items: 287
# Test items: 71
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: captain-sonar
# Train items: 68
# Test items: 17
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: clue
# Train items: 630
# Test items: 157
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: acquire
# Train items: 292
# Test items: 73
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: tikal
# Train items: 406
# Test items: 101
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: thurn-and-taxis
# Train items: 237
# Test items: 59
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: tiny-epic-galaxies
# Train items: 204
# Test items: 50
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: kingsburg
# Train items: 132
# Test items: 32
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: res-arcana
# Train items: 78
# Test items: 19
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: catan-cities-knights
# Train items: 240
# Test items: 59
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: decrypto
# Train items: 74
# Test items: 18
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: clans-caledonia
# Train items: 276
# Test items: 69
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: jamaica
# Train items: 116
# Test items: 28
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: twilight-imperium-third-edition
# Train items: 476
# Test items: 118
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: war-ring-second-edition
# Train items: 294
# Test items: 73
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: through-ages-story-civilization
# Train items: 308
# Test items: 76
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: formula-d
# Train items: 319
# Test items: 79
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: roll-player
# Train items: 184
# Test items: 46
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: concept
# Train items: 124
# Test items: 30
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: mice-and-mystics
# Train items: 284
# Test items: 71
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: apples-apples
# Train items: 120
# Test items: 29
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: arboretum
# Train items: 201
# Test items: 50
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: catan-seafarers
# Train items: 249
# Test items: 62
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 143
# ---------------------------
# Category: food-chain-magnate
# Train items: 219
# Test items: 54
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: kemet
# Train items: 268
# Test items: 66
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: grand-austria-hotel
# Train items: 214
# Test items: 53
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: isle-cats
# Train items: 274
# Test items: 68
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: teotihuacan-city-gods
# Train items: 252
# Test items: 62
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: zombicide
# Train items: 323
# Test items: 80
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: tapestry
# Train items: 404
# Test items: 101
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: aeons-end
# Train items: 117
# Test items: 29
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: legends-andor
# Train items: 274
# Test items: 68
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: inis
# Train items: 220
# Test items: 54
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: potion-explosion
# Train items: 200
# Test items: 50
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: zombie-dice
# Train items: 96
# Test items: 24
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: disney-villainous
# Train items: 132
# Test items: 33
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: innovation
# Train items: 227
# Test items: 56
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: pillars-earth
# Train items: 240
# Test items: 59
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: pandemic-brink
# Train items: 199
# Test items: 49
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: mr-jack
# Train items: 212
# Test items: 53
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: fluxx
# Train items: 109
# Test items: 27
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: barenpark
# Train items: 163
# Test items: 40
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: harry-potter-hogwarts-battle
# Train items: 188
# Test items: 46
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: russian-railroads
# Train items: 233
# Test items: 58
# ---------------------------
# Category: rest
# Train items: 565
# Test items: 141
# ---------------------------
# Category: tiny-towns
# Train items: 289
# Test items: 72
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: biblios
# Train items: 181
# Test items: 45
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: underwater-cities
# Train items: 254
# Test items: 63
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: spot-it
# Train items: 290
# Test items: 72
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: battle-line
# Train items: 116
# Test items: 28
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: trajan
# Train items: 273
# Test items: 68
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: carcassonne-expansion-2-traders-builders
# Train items: 140
# Test items: 34
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: rummikub
# Train items: 456
# Test items: 114
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: cant-stop
# Train items: 249
# Test items: 62
# ---------------------------
# Category: rest
# Train items: 364
# Test items: 90
# ---------------------------
# Category: escape-curse-temple
# Train items: 19
# Test items: 4
# ---------------------------
# Category: rest
# Train items: 24
# Test items: 5
# ---------------------------
# Category: uno
# Train items: 236
# Test items: 59
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: mind
# Train items: 153
# Test items: 38
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: eclipse
# Train items: 468
# Test items: 117
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: tigris-euphrates
# Train items: 360
# Test items: 90
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: welcome
# Train items: 96
# Test items: 23
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: 6-nimmt
# Train items: 121
# Test items: 30
# ---------------------------
# Category: rest
# Train items: 0
# Test items: 0
# ---------------------------
# Category: caylus
# Train items: 336
# Test items: 84
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: shadows-over-camelot
# Train items: 259
# Test items: 64
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: tsuro
# Train items: 253
# Test items: 63
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: cards-against-humanity
# Train items: 44
# Test items: 11
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: time-stories
# Train items: 132
# Test items: 32
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: el-grande
# Train items: 209
# Test items: 52
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: smash
# Train items: 134
# Test items: 33
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: nemesis
# Train items: 432
# Test items: 108
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: architects-west-kingdom
# Train items: 374
# Test items: 93
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: one-night-ultimate-werewolf
# Train items: 119
# Test items: 29
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: blokus
# Train items: 168
# Test items: 42
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: camel
# Train items: 240
# Test items: 59
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: cascadia
# Train items: 267
# Test items: 66
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: secret-hitler
# Train items: 75
# Test items: 18
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: feast-odin
# Train items: 330
# Test items: 82
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: ingenious
# Train items: 173
# Test items: 43
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: mechs-vs-minions
# Train items: 193
# Test items: 48
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: point-salad
# Train items: 126
# Test items: 31
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------
# Category: telestrations
# Train items: 81
# Test items: 20
# ---------------------------
# Category: rest
# Train items: 576
# Test items: 144
# ---------------------------

# %% [markdown]
# # Auto Modeling

# %%
import os
import datetime
import json
import joblib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import layers, regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping


class AutoModeling:
    def __init__(self, main_dir, img_height=256, img_width=256, batch_size=8, learning_rate=0.000025, epochs=30,
                 patience=8):
        """
        Initializes the AutoModeling class.

        Args:
            main_dir (str): The main directory containing subdirectories for each game.
            img_height (int): The height of the input images (default: 256).
            img_width (int): The width of the input images (default: 256).
            batch_size (int): The batch size for training (default: 8).
            learning_rate (float): The learning rate for the optimizer (default: 0.000025).
            epochs (int): The number of epochs to train the model (default: 30).
            patience (int): The patience value for early stopping (default: 8).
        """
        self.main_dirs = [os.path.join(main_dir, game) for game in os.listdir(main_dir)]
        self.img_height = img_height
        self.img_width = img_width
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.patience = patience
        self.model_info = {}

    def train_test_val(self, path):
        """
        Create train, test, and validation datasets for a given game.

        Args:
            path (str): The path to the game directory.

        Returns:
            tuple: A tuple containing the train, test, and validation datasets.
        """
        game_name = os.path.split(path)[-1]
        class_names = [game_name, 'rest']
        path_train = os.path.join(path, 'train')
        path_test = os.path.join(path, 'test')
        train_ds = keras.utils.image_dataset_from_directory(
            path_train,
            validation_split=0.2,
            subset='training',
            image_size=(self.img_height, self.img_width),
            batch_size=self.batch_size,
            label_mode='categorical',
            seed=42,
            class_names=class_names
        )

        val_ds = keras.utils.image_dataset_from_directory(
            path_train,
            validation_split=0.2,
            subset='validation',
            image_size=(self.img_height, self.img_width),
            batch_size=self.batch_size,
            label_mode='categorical',
            seed=42,
            class_names=class_names
        )

        test_ds = keras.utils.image_dataset_from_directory(
            path_test,
            validation_split=None,
            subset=None,
            image_size=(self.img_height, self.img_width),
            batch_size=self.batch_size,
            label_mode='categorical',
            interpolation='bilinear',
            seed=42,
            class_names=class_names
        )

        return train_ds, test_ds, val_ds

    def model_set_up(self):
        """
        Set up the model architecture using EfficientNetB0 as the base model.
        """
        efficient_model = EfficientNetB0(
            include_top=False,
            weights='imagenet',
            input_shape=(self.img_height, self.img_width, 3)
        )
        model = Sequential()
        model.add(keras.layers.RandomFlip(mode="horizontal_and_vertical"))
        model.add(keras.layers.RandomZoom(height_factor=(-0.3, -0.2), interpolation="bilinear"))
        model.add(efficient_model)
        model.add(layers.Flatten())
        model.add(layers.Dense(128, activation='relu', kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)))
        model.add(layers.Dropout(0.5))
        model.add(layers.Dense(2, activation='sigmoid'))

        opt = keras.optimizers.Adam(self.learning_rate)
        model.compile(
            optimizer=opt,
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )

        print(f"Model architecture:\n{model.summary()}")
        self.model = model

    def model_fit(self, train_ds, val_ds):
        """
        Train the model using the provided train and validation datasets.

        Args:
            train_ds (tf.data.Dataset): The training dataset.
            val_ds (tf.data.Dataset): The validation dataset.

        Returns:
            tf.keras.callbacks.History: The training history.
        """
        early_stopping = EarlyStopping(monitor='val_loss', patience=self.patience)
        return self.model.fit(
            train_ds,
            validation_data=val_ds,
            epochs=self.epochs,
            batch_size=self.batch_size,
            callbacks=[early_stopping]
        )

    def evaluate_model(self, test_ds):
        """
        Evaluate the trained model using the provided test dataset.

        Args:
            test_ds (tf.data.Dataset): The test dataset.

        Returns:
            tuple: A tuple containing the test loss and test accuracy.
        """
        test_loss, test_acc = self.model.evaluate(test_ds)
        print('Test loss:', test_loss)
        print('Test accuracy:', test_acc)
        return test_loss, test_acc

    def save_model_info(self, model_name, train_time, history, test_acc, path):
        """
        Save the model information to a JSON file.

        Args:
            model_name (str): The name of the model.
            train_time (float): The total training time in seconds.
            history (tf.keras.callbacks.History): The training history.
            test_acc (float): The test accuracy.
            path (str): The path to save the model information.
        """
        model_info = {
            'log_start': datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            'log_end': datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            'model': model_name,
            'train_time': train_time,
            'train_time_per_epoch': train_time / len(history.history['loss']),
            'train_acc': history.history['accuracy'][-1],
            'val_acc': history.history['val_accuracy'][-1],
            'test_acc': test_acc,
            'training_details': {
                'epochs': len(history.history['loss']),
                'loss': history.history['loss'],
                'val_loss': history.history['val_loss'],
                'accuracy': history.history['accuracy'],
                'val_accuracy': history.history['val_accuracy']
            }
        }

        if os.path.exists(f'{path}/model_info.json'):
            with open(f'{path}/model_info.json', 'r') as f:
                self.model_info = json.load(f)

        self.model_info[model_name] = model_info

        with open(f'{path}/model_info.json', 'w') as f:
            json.dump(self.model_info, f, indent=4)

    def save_model(self, model_name, models_path):
        """
        Save the trained model to a joblib file.

        Args:
            model_name (str): The name of the model.
            models_path (str): The path to save the trained models.
        """
        joblib.dump(self.model, f'{models_path}/{model_name}.joblib')
        del self.model

# %%
list_of_dirs = os.listdir('images/main_separated')

# %%
['images/main_separated' + '/' + game for game in os.listdir('images/main_separated')]

# %%
model_handler = AutoModeling(main_dir='images/main_separated', batch_size=32)

# %%
for i in range(16, 20):
  path = model_handler.main_dirs[i]
  train_ds, test_ds, val_ds = model_handler.train_test_val(path)
  model_handler.model_set_up()
  start_time = time.time()
  history = model_handler.model_fit(train_ds, val_ds)
  end_time = time.time()
  train_time = end_time - start_time
  test_loss, test_acc = model_handler.evaluate_model(test_ds)
  model_handler.save_model_info(model_name=f'{path.split("/")[-1]} model', train_time=train_time, history=history, test_acc=test_acc, path='models')
  model_handler.save_model(model_name=f'{path.split("/")[-1]} model', models_path='models')
  del train_ds, test_ds, val_ds, history
# Out:
# Found 904 files belonging to 2 classes.
# Using 724 files for training.
# Found 904 files belonging to 2 classes.
# Using 180 files for validation.
# Found 228 files belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step
# <keras.engine.sequential.Sequential object at 0x7fd7e6d4e050> saved successfully.
# Epoch 1/30
# 23/23 [==============================] - 102s 1s/step - loss: 1.5671 - accuracy: 0.5456 - val_loss: 1.1841 - val_accuracy: 0.6333
# Epoch 2/30
# 23/23 [==============================] - 9s 355ms/step - loss: 1.2419 - accuracy: 0.6478 - val_loss: 1.0404 - val_accuracy: 0.7056
# Epoch 3/30
# 23/23 [==============================] - 9s 353ms/step - loss: 1.0843 - accuracy: 0.6948 - val_loss: 0.9478 - val_accuracy: 0.7778
# Epoch 4/30
# 23/23 [==============================] - 9s 357ms/step - loss: 0.9606 - accuracy: 0.7818 - val_loss: 0.9129 - val_accuracy: 0.7944
# Epoch 5/30
# 23/23 [==============================] - 9s 358ms/step - loss: 0.9092 - accuracy: 0.8232 - val_loss: 0.8800 - val_accuracy: 0.8222
# Epoch 6/30
# 23/23 [==============================] - 9s 359ms/step - loss: 0.8519 - accuracy: 0.8384 - val_loss: 0.8625 - val_accuracy: 0.8167
# Epoch 7/30
# 23/23 [==============================] - 9s 359ms/step - loss: 0.8074 - accuracy: 0.8633 - val_loss: 0.8501 - val_accuracy: 0.8278
# Epoch 8/30
# 23/23 [==============================] - 9s 359ms/step - loss: 0.7616 - accuracy: 0.8812 - val_loss: 0.8534 - val_accuracy: 0.8278
# Epoch 9/30
# 23/23 [==============================] - 9s 364ms/step - loss: 0.7224 - accuracy: 0.8923 - val_loss: 0.8524 - val_accuracy: 0.8278
# Epoch 28/30
# 28/28 [==============================] - 11s 368ms/step - loss: 0.5560 - accuracy: 0.9667 - val_loss: 0.6643 - val_accuracy: 0.9217
# Epoch 29/30
# 28/28 [==============================] - 11s 367ms/step - loss: 0.5349 - accuracy: 0.9828 - val_loss: 0.6513 - val_accuracy: 0.9263
# Epoch 30/30
# 28/28 [==============================] - 11s 369ms/step - loss: 0.5419 - accuracy: 0.9816 - val_loss: 0.6483 - val_accuracy: 0.9401
# 9/9 [==============================] - 15s 153ms/step - loss: 0.6950 - accuracy: 0.9077
# Test loss: 0.6949691772460938
# Test accuracy: 0.9077490568161011
# Found 927 files belonging to 2 classes.
# Using 742 files for training.
# Found 927 files belonging to 2 classes.
# Using 185 files for validation.
# Found 221 files belonging to 2 classes.
# <keras.engine.sequential.Sequential object at 0x7fd733282710> saved successfully.
# Epoch 1/30
# 24/24 [==============================] - 81s 1s/step - loss: 1.5043 - accuracy: 0.5970 - val_loss: 1.1002 - val_accuracy: 0.6649
# Epoch 2/30
# 24/24 [==============================] - 9s 354ms/step - loss: 1.3005 - accuracy: 0.6334 - val_loss: 1.0278 - val_accuracy: 0.7351
# Epoch 3/30
# 24/24 [==============================] - 9s 357ms/step - loss: 1.1826 - accuracy: 0.7022 - val_loss: 1.0063 - val_accuracy: 0.7405
# Epoch 4/30
# 24/24 [==============================] - 9s 356ms/step - loss: 1.1403 - accuracy: 0.7049 - val_loss: 0.9923 - val_accuracy: 0.7730
# Epoch 5/30
# 24/24 [==============================] - 9s 363ms/step - loss: 1.0593 - accuracy: 0.7547 - val_loss: 0.9703 - val_accuracy: 0.7676
# Epoch 6/30
# 24/24 [==============================] - 9s 357ms/step - loss: 0.9931 - accuracy: 0.7763 - val_loss: 0.9503 - val_accuracy: 0.7784
# Epoch 7/30
# 24/24 [==============================] - 9s 359ms/step - loss: 0.8931 - accuracy: 0.8167 - val_loss: 0.9360 - val_accuracy: 0.7838
# Epoch 8/30
# 24/24 [==============================] - 9s 359ms/step - loss: 0.8738 - accuracy: 0.8248 - val_loss: 0.9082 - val_accuracy: 0.7676
# Epoch 9/30
# 24/24 [==============================] - 9s 358ms/step - loss: 0.8413 - accuracy: 0.8194 - val_loss: 0.9045 - val_accuracy: 0.7946
# Epoch 10/30
# 24/24 [==============================] - 9s 361ms/step - loss: 0.8078 - accuracy: 0.8612 - val_loss: 0.9059 - val_accuracy: 0.8054
# Epoch 11/30
# 24/24 [==============================] - 9s 360ms/step - loss: 0.7858 - accuracy: 0.8612 - val_loss: 0.8838 - val_accuracy: 0.8000
# Epoch 12/30
# 24/24 [==============================] - 9s 364ms/step - loss: 0.7606 - accuracy: 0.8693 - val_loss: 0.8799 - val_accuracy: 0.8054
# Epoch 13/30
# 24/24 [==============================] - 9s 361ms/step - loss: 0.7194 - accuracy: 0.8774 - val_loss: 0.8691 - val_accuracy: 0.8054
# Epoch 14/30
# 24/24 [==============================] - 9s 361ms/step - loss: 0.7314 - accuracy: 0.8962 - val_loss: 0.8718 - val_accuracy: 0.8000
# Epoch 15/30
# 24/24 [==============================] - 9s 362ms/step - loss: 0.7216 - accuracy: 0.8908 - val_loss: 0.8641 - val_accuracy: 0.8216
# Epoch 16/30
# 24/24 [==============================] - 9s 362ms/step - loss: 0.7143 - accuracy: 0.9070 - val_loss: 0.8679 - val_accuracy: 0.8270
# Epoch 17/30
# 24/24 [==============================] - 9s 364ms/step - loss: 0.6739 - accuracy: 0.9151 - val_loss: 0.8717 - val_accuracy: 0.8216
# Epoch 18/30
# 24/24 [==============================] - 9s 365ms/step - loss: 0.7070 - accuracy: 0.9043 - val_loss: 0.8746 - val_accuracy: 0.8270
# Epoch 19/30
# 24/24 [==============================] - 9s 365ms/step - loss: 0.6830 - accuracy: 0.9097 - val_loss: 0.8690 - val_accuracy: 0.8216
# Epoch 20/30
# 24/24 [==============================] - 9s 361ms/step - loss: 0.6539 - accuracy: 0.9232 - val_loss: 0.8690 - val_accuracy: 0.8216
# 7/7 [==============================] - 12s 200ms/step - loss: 0.9575 - accuracy: 0.7873
# Test loss: 0.9575069546699524
# Test accuracy: 0.7873303294181824
# Found 992 files belonging to 2 classes.
# Using 794 files for training.
# Found 992 files belonging to 2 classes.
# Using 198 files for validation.
# Found 254 files belonging to 2 classes.
# <keras.engine.sequential.Sequential object at 0x7fd7374d5ed0> saved successfully.
# Epoch 1/30
# 25/25 [==============================] - 82s 1s/step - loss: 1.5438 - accuracy: 0.5428 - val_loss: 1.4017 - val_accuracy: 0.5606
# Epoch 2/30
# 25/25 [==============================] - 10s 369ms/step - loss: 1.2569 - accuracy: 0.6549 - val_loss: 1.2583 - val_accuracy: 0.6212
# Epoch 3/30
# 25/25 [==============================] - 10s 366ms/step - loss: 1.1189 - accuracy: 0.7028 - val_loss: 1.1461 - val_accuracy: 0.6768
# Epoch 4/30
# 25/25 [==============================] - 10s 367ms/step - loss: 0.9756 - accuracy: 0.7733 - val_loss: 1.0673 - val_accuracy: 0.7374
# Epoch 5/30
# 25/25 [==============================] - 10s 368ms/step - loss: 0.9178 - accuracy: 0.7997 - val_loss: 1.0455 - val_accuracy: 0.7424
# Epoch 6/30
# 25/25 [==============================] - 10s 372ms/step - loss: 0.9260 - accuracy: 0.7985 - val_loss: 0.9970 - val_accuracy: 0.7576
# Epoch 7/30
# 25/25 [==============================] - 10s 368ms/step - loss: 0.8269 - accuracy: 0.8438 - val_loss: 0.9536 - val_accuracy: 0.7980
# Epoch 8/30
# 25/25 [==============================] - 10s 371ms/step - loss: 0.8113 - accuracy: 0.8552 - val_loss: 0.9434 - val_accuracy: 0.7929
# Epoch 9/30
# 25/25 [==============================] - 10s 370ms/step - loss: 0.8100 - accuracy: 0.8514 - val_loss: 0.9123 - val_accuracy: 0.8030
# Epoch 10/30
# 25/25 [==============================] - 10s 378ms/step - loss: 0.7775 - accuracy: 0.8741 - val_loss: 0.8744 - val_accuracy: 0.8232
# Epoch 11/30
# 25/25 [==============================] - 10s 371ms/step - loss: 0.7496 - accuracy: 0.8904 - val_loss: 0.8521 - val_accuracy: 0.8434
# Epoch 12/30
